# %% [markdown]
# <a href="https://colab.research.google.com/github/AxdKyn13/Projects-Trial/blob/main/Code_Final_Project_Deep_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Import library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pytorch as torch
import torch.nn as nn
from google.colab import drive

# %% [markdown]
# Load data

# %%
drive.mount('/content/drive')
dataS_1 = pd.read_csv('/content/drive/MyDrive/TRKB Final Project/Deep Learning 2026/Code & Dataset/dataS_1.csv')

# %% [markdown]
# Raw Data

# %%
#Tampilin data mentah

# %% [markdown]
# Pre-processing

# %%
#Window size: 30, step size: 32, normalize pake minmaxscaler,
#Filter dulu baru diwindow
#Splitting: 60% training, 20% testing, 20% validasi

# %% [markdown]
# Processed data example

# %%
#Tampilin contoh data yg udah di pre proses

# %% [markdown]
# Model

# %%
#Autoencoder
#LSTM: pakai

# %% [markdown]
# Training

# %%
#Training, grafik akurasi dan validasi
#Spec: optimizer: adam, epoch: 500, early stopping (patience: 30), batch size: 1000, learning rate: 5 x 10^-6, total window katanya 43K

# %% [markdown]
# Evaluate

# %%
#Akurasi, presisi, recall, f1, confusion matrix,
